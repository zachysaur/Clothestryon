# %% [markdown]
# <a href="https://colab.research.google.com/github/poomshift/MagicClothing-Colab/blob/main/MagicClothing_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![aad.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ***MagicClothing | สร้างนางแบบมาใส่เสื้อของเรา***
#
# เป็นโปรเจคที่ต่อยอดมาจาก [MagicClothing ](https://github.com/ShineChen1024/MagicClothing)ของ ShineChen1024
#
# ผมนำมาทำให้เข้าใช้งานง่ายขึ้นผ่าน Google Colab สำหรับคนที่การ์ดจอไม่แรง
#
# ขั้นตอนการใช้งาน [>>คลิก<<](https://www.facebook.com/photo/?fbid=310720852056511&set=a.101760342952564)
#
# ------------
#
# พบเจอปัญหา แจ้งที่ [Facebook/promptalchemist](https://facebook.com/PromptAlchemist)
#
# Google Colab สำหรับ Stable Diffusion WebUI [>>คลิก<<](https://colab.research.google.com/github/poomshift/PromptAlchemist_SD_Webui_Colab/blob/main/PromptAlchemist_SD_Webui_Colab.ipynb#scrollTo=1F-zYI2-Uo0a)

# %%
#@markdown # 1. ติดตั้ง Dependencies ก่อน
from IPython.display import clear_output
from IPython.display import Javascript
import ipywidgets as widgets
display(Javascript('''google.colab.output.setIframeHeight(0, true, {maxHeight: 200})'''))
def inf(msg, style, wdth): inf = widgets.Button(description=msg, disabled=True, button_style=style, layout=widgets.Layout(min_width=wdth));display(inf)

# !git clone https://github.com/poomshift/MagicClothing-Colab
# !pip install torch==2.0.1 torchvision==0.15.2 diffusers==0.25.1 opencv-python==4.9.0.80  transformers==4.31.0 gradio==4.16.0 safetensors==0.3.1 controlnet-aux==0.0.6 accelerate==0.21.0
# !wget -P /content/MagicClothing-Colab/checkpoints https://huggingface.co/ShineChen1024/MagicClothing/resolve/main/cloth_segm.pth
# !wget -P /content/MagicClothing-Colab/checkpoints https://huggingface.co/ShineChen1024/MagicClothing/resolve/main/magic_clothing_768_vitonhd_joint.safetensors

clear_output()
inf('\u2714 Done','success', '50px')

# %%
#@markdown # 2. Run โปรแกรม
from IPython.display import clear_output
from IPython.display import Javascript
import ipywidgets as widgets
display(Javascript('''google.colab.output.setIframeHeight(0, true, {maxHeight: 200})'''))

# %cd /content/MagicClothing-Colab
# !python gradio_generate.py --model_path /content/MagicClothing-Colab/checkpoints/magic_clothing_768_vitonhd_joint.safetensors --enable_cloth_guidance
